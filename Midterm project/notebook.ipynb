# %%
def cargar_dataset_kagglehub(dataset_id):
    import kagglehub, os, pandas as pd

    path = kagglehub.dataset_download(dataset_id)
    for root, dirs, files in os.walk(path):
        for file in files:
            full_path = os.path.join(root, file)
            print("Archivo encontrado:", full_path)
            if file.endswith(".csv"):
                return pd.read_csv(full_path)
            elif file.endswith(".xlsx"):
                return pd.read_excel(full_path)
    raise FileNotFoundError("No se encontró ningún archivo CSV o Excel en el dataset.")

df = cargar_dataset_kagglehub("davidjhonatan/videojuegos")
# Out:
# ...
# 100%|██████████| 853k/853k [00:00<00:00, 20.5MB/s]
# Extracting files...
# Archivo encontrado: /home/codespace/.cache/kagglehub/datasets/davidjhonatan/videojuegos/versions/1/Tagged-Data-Final.csv

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("/home/codespace/.cache/kagglehub/datasets/davidjhonatan/videojuegos/versions/1/Tagged-Data-Final.csv")
df.head().T
# Out:
#                                        0                       1  \
# Name             .hack//Infection Part 1  .hack//Mutation Part 2
# Year_of_Release                   2002.0                  2002.0
# Genre                       Role-Playing            Role-Playing
# Publisher                          Atari                   Atari
# NA_Sales                            0.49                    0.23
# EU_Sales                            0.38                    0.18
# JP_Sales                            0.26                     0.2
# Other_Sales                         0.13                    0.06
# Global_Sales                        1.27                    0.68
# Critic_Score                        75.0                    76.0
# Critic_Count                        35.0                    24.0
# User_Score                           8.5                     8.9
# User_Count                          60.0                    81.0
# ...

# %%
df.dtypes
# Out:
# Name                object
# Year_of_Release    float64
# Genre               object
# Publisher           object
# NA_Sales           float64
# EU_Sales           float64
# JP_Sales           float64
# Other_Sales        float64
# Global_Sales       float64
# Critic_Score       float64
# Critic_Count       float64
# User_Score         float64
# User_Count         float64
# Developer           object
# Rating              object
# Story Focus         object
# Gameplay Focus      object
# Series              object
# dtype: object

# %%
df.describe()
# Out:
#        pairing_quality
# count     34933.000000
# mean          3.015115
# std           1.409591
# min           1.000000
# 25%           2.000000
# 50%           3.000000
# 75%           4.000000
# max           5.000000

# %%
object_columns = df.select_dtypes(include=['object']).columns
numerical_columns = df['pairing_quality']

# %%
for col in object_columns:
    print(f"Columna: {col}")
    print(df[col].unique())
    print("\n")
# Out:
# Columna: wine_type
# ['Syrah/Shiraz' 'Grenache' 'Madeira' 'Cabernet Sauvignon' 'Viognier'
#  'Pinot Noir' 'Albariño' 'Sangiovese' 'Grüner Veltliner' 'Sauternes'
#  'Cava' 'Riesling (dry)' 'Chardonnay' 'Nebbiolo' 'Port' 'Ice Wine'
#  'Gewürztraminer' 'Merlot' 'Champagne' 'Torrontés' 'Sauvignon Blanc'
#  'Malbec' 'Zinfandel' 'Barbera' 'Chenin Blanc' 'Provence Rosé'
#  'Gamay (Beaujolais)' 'Tempranillo' 'White Zinfandel']
#
#
# Columna: wine_category
# ['Red' 'Fortified' 'White' 'Dessert' 'Sparkling' 'Rosé']
#
#
# Columna: food_item
# ['smoked sausage' 'charcuterie board' 'lemon tart' 'roast lamb'
#  'duck à l’orange' 'citrus salad' 'oysters' 'cheese platter'
#  'bacon burger' 'chicken curry' 'vegetable curry' 'alfredo pasta'
#  'Thai curry' 'roast chicken with herbs' 'shrimp scampi' 'stir-fried tofu'
#  'cheesecake' 'beef stew' 'grilled burger' 'Indian vindaloo'
#  'mushroom risotto' 'grilled salmon' 'mac and cheese' 'sorbet'
# ...
